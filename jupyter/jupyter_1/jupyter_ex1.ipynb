# %%
import csv

f=open('hospital_2019.csv', 'r', encoding='utf-8')
lines = csv.reader(f)
header = next(lines)
print('번호', '치과병원명', header[3], header[6])

num = 1
for line in lines:
    if('치과병원' == line[1]) and (line[2]== '전남'):
        print(num, end='.')
        print(line[0], line[3], line[6],sep='/')
        num+=1

f.close()
# Out:
# 번호 치과병원명 주소 총의사수
# 1.국군함평치과병원/전라남도 함평군 해보면 신해로 1027 ()/3
# 2.그랜드치과병원/전라남도 여수시 시청로 48  (학동)/3
# 3.모아치과병원/전라남도 여수시 소호로 618  (학동)/8
# 4.미르치과병원/전라남도 목포시 백년대로 319  (상동)/17
# 5.순천미르치과병원/전라남도 순천시 연향번영길 118  (연향동)/5
# 6.신우치과병원/전라남도 무안군 삼향읍 남악3로 50 ()/9
# 7.예닮치과병원/전라남도 목포시 비파로 91 91/11

# %%
import csv

f=open('hospital_2019.csv', 'r', encoding='utf-8')
lines = csv.reader(f)
header = next(lines)
result = 0

for line in lines:
        if line[2]=='제주' and line[1]=='의원' and int(line[5]) >= 20160101 and int(line[5]) <= 20181231:
            result += 1

print('2016~2018년 3개년간 개원한 제주도의 의원의 수 = %d 개' %result)
f.close()
# Out:
# 2016~2018년 3개년간 개원한 제주도의 의원의 수 = 104 개

# %%
import csv

f=open('hospital_2019.csv', 'r', encoding='utf-8')
lines = csv.reader(f)
header = next(lines)
for line in lines:
    if '청구빌딩' in line[3] and '안양' in line[3]:
        print('병원명 : %s' %line[0])
        print('병원종류 : %s' %line[1])
        print('주소 : %s' %line[3])
        print('전화번호 : %s'%line[4])
        print('-' * 40)
# Out:
# 병원명 : 서울 힐링 치과의원
# 병원종류 : 치과의원
# 주소 : 경기도 안양시 동안구 귀인로 216 (평촌동, 청구빌딩)
# 전화번호 : 031-381-2929
# ----------------------------------------
# 병원명 : 호성한의원
# 병원종류 : 한의원
# 주소 : 경기도 안양시 동안구 귀인로 216 2층 (평촌동, 청구빌딩)
# 전화번호 : 031-384-1075
# ----------------------------------------

# %%
import csv

f=open('hospital_2019.csv', 'r', encoding='utf-8')
lines = csv.reader(f)
header = next(lines)
print('번호', '한의원명', header[4], header[6])

num = 1
for line in lines:
    if('한의원' in line[1]) and ('강원' in line[2]) and int(line[5]) >= 20190101 and int(line[5]) <= 20191231:
        print(num, end='.')
        print(line[0], line[4], line[6],sep='/')
        num+=1
# Out:
# 번호 한의원명 전화번호 총의사수
# 1.경희 고성한의원/033-681-6260/1
# 2.남대천한의원/033-642-0751/2
# 3.남부한의원/033-735-9000/2
# 4.단주한의원/033-648-7900/1
# 5.대활한의원/033-632-6964/1
# 6.맘드림한의원/033-647-1223/1
# 7.백세한의원/033-521-1921/1
# 8.의함다래평생한의원/033-766-8925/1
# 9.제일편한 한의원/033-262-1900/1
# 10.주천동리한의원/-/1
# 11.중앙한의원/033-482-5355/1
# 12.청담한의원/033-647-1497/1
# 13.청운한의원/033-651-5005/1
# 14.춘천한방한의원/033-260-7000/1
# 15.팔팔한의원/033-264-1588/1

# %%
import csv

f=open('hospital_2019.csv', 'r', encoding='utf-8')
lines = csv.reader(f)
header = next(lines)
print('번호', header[0], header[1], header[3], header[5])

num = 1
for line in lines:
    if('부산' == line[2]) and ('삼성' in line[0]):
        print(num, end='.')
        print(line[0], line[1], line[3], line[5],sep='/')
        num+=1
# Out:
# 번호 병원명 종류 주소 개설일자
# 1.덕천삼성정형외과의원/의원/부산광역시 북구 만덕대로 58 3층 (덕천동)/20170427
# 2.르노삼성자동차부속의원/의원/부산광역시 강서구 르노삼성대로 61 (신호동)/20140827
# 3.비에스(BS)삼성안과의원/의원/부산광역시 중구 구덕로 90 (남포동6가)/20131101
# 4.삼성내과엠알영상의학과의원/의원/부산광역시 사하구 낙동남로 1392 3,4,9～12층 (하단동)/20081121
# 5.삼성뉴방외과의원/의원/부산광역시 해운대구 해운대로 794 603호 (좌동, 삼정엘리움)/20110725
# 6.삼성메디이비인후과의원/의원/부산광역시 동구 중앙대로 197 (초량동)/20131011
# 7.삼성메디칼의원/의원/부산광역시 연제구 중앙대로 1125 에이동 408호 (연산동, CT타워)/20170215
# 8.삼성메디칼의원/의원/부산광역시 부산진구 전포대로 294 1동 303층 (전포동, 서면한신아파트)/20100512
# 9.삼성메디칼의원/의원/부산광역시 서구 대티로 179 3층 (서대신동3가)/20040302
# 10.삼성서울내과의원/의원/부산광역시 동래구 사직로70번길 76 (사직동)/20130816
# 11.삼성스마트신경과의원/의원/부산광역시 동래구 중앙대로 1523 SKHUBSKY 2층 B2-6,7,8,9,12,13,14,15호 (온천동)/20190418
# 12.삼성안과의원/의원/부산광역시 사하구 낙동대로 454 3층 (당리동)/19980309
# 13.삼성안과의원/의원/부산광역시 기장군 기장읍 차성남로51번길 30 4층/20060428
# 14.삼성연합의원/의원/부산광역시 동래구 여고북로 160 2,4층 (사직동)/20080325
# 15.삼성의원/의원/부산광역시 동래구 충렬대로 252 (수안동)/20120627
# 16.삼성의원/의원/부산광역시 서구 구덕로 102-1 (충무동1가)/20080618
# 17.삼성의원/의원/부산광역시 해운대구 반송로924번길 13-1 (반송동)/20051103
# ...
